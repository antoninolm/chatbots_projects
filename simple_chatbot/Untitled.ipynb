# %% [markdown]
# <p style="text-align: center; font-size: 30px;"><b>Simple Chatbot</b></p>

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 1</b></p>
# <p>Define a function called coffee_bot() that prints out the statement 'Welcome to the cafe!'. At the bottom of the script, call your function so that, when you run the script, the greeting is displayed. As you progress through the project, you can run the script at any time to see your changes after saving.</p>

# %%
def coffee_bot():
    print("Welcome to the cafe!")


coffee_bot()
# Out:
# Welcome to the cafe!

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 2</b></p>
# <p>Define a function called get_size() that asks the user for the size of their drink using input() and stores the response in a variable called res: 'What size drink can I get for you? [a] Small [b] Medium [c] Large'. Return res from the function so that it contains the letter corresponding to the selection. Inside coffee_bot(), call get_size(), store the returned value in a variable called size, and print size to see the value.</p>

# %%
def get_size():
    res = input(
        "What size drink can I get for you? \n"
        "[a] Small \n"
        "[b] Medium \n"
        "[c] Large \n"
        "> "
    )
    return res

# %%
def coffee_bot():
    print("Welcome to the cafe!")

    size = get_size()
    print(size)


coffee_bot()
# Out:
# Welcome to the cafe!
# What size drink can I get for you?
# [a] Small
# [b] Medium
# [c] Large
# > d
# d

# %% [markdown]
# <p style="font-size:  16px;"><b>Task 3</b></p>
# <p>Update the get_size() function so that it returns the selected size as text instead of the letter corresponding to the user’s selection. Use conditional statements such that if res is 'a', return 'small'; if res is 'b', return 'medium'; and if res is 'c', return 'large'. Run the script to see which value gets printed.</p>

# %%
def get_size():
    res = input(
        "What size drink can I get for you? \n"
        "[a] Small \n"
        "[b] Medium \n"
        "[c] Large \n"
        "> "
    )

    if res == "a":
        return "small"
    elif res == "b":
        return "medium"
    elif res == "c":
        return "large"

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 4</b></p>
# <p>Add an else block to the conditional statements in get_size() to handle any input other than 'a', 'b', or 'c'. In this else block, call get_size() again and return its returned value so that the user is repeatedly prompted until a valid selection is entered.</p>

# %%
def get_size():
    res = input(
        "What size drink can I get for you? \n"
        "[a] Small \n"
        "[b] Medium \n"
        "[c] Large \n"
        "> "
    )

    if res == "a":
        return "small"
    elif res == "b":
        return "medium"
    elif res == "c":
        return "large"
    else:
        return get_size()

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 5</b></p>
# <p>Define a function called print_message() that prints: 'I'm sorry, I did not understand your selection. Please enter the corresponding letter for your response.'. In the else block of get_size(), call print_message() before returning get_size() so that the user sees an error message whenever their selection is invalid.</p>

# %%
def print_message():
    print(
        "I'm sorry, I did not understand your selection. "
        "Please enter the corresponding letter for your response."
    )

# %%
def get_size():
    res = input(
        "What size drink can I get for you? \n"
        "[a] Small \n"
        "[b] Medium \n"
        "[c] Large \n"
        "> "
    )

    if res == "a":
        return "small"
    elif res == "b":
        return "medium"
    elif res == "c":
        return "large"
    else:
        print_message()
        return get_size()

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 6</b></p>
# <p>Define a function called get_drink_type() that asks the user what type of drink they would like using input() with the options: 'What type of drink would you like? [a] Brewed Coffee [b] Mocha [c] Latte'. Store the response in a variable called res and return res for now. Inside coffee_bot(), under the call to get_size(), call get_drink_type(), store the returned value in a variable called drink_type, and print drink_type to see the value.</p>

# %%
def get_drink_type():
    res = input(
        "What type of drink would you like? \n"
        "[a] Brewed Coffee \n"
        "[b] Mocha \n"
        "[c] Latte \n"
        "> "
    )
    return res

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 7</b></p>
# <p>Update get_drink_type() by deleting the previous return statement and adding conditional statements such that if res is 'a', return 'brewed coffee'; if res is 'b', return 'mocha'; and if res is 'c', return 'latte'. For any other input, call print_message() and return the value obtained from calling get_drink_type() again so that the user is prompted until a valid drink type is selected.</p>

# %%
def get_drink_type():
    res = input(
        "What type of drink would you like? \n"
        "[a] Brewed Coffee \n"
        "[b] Mocha \n"
        "[c] Latte \n"
        "> "
    )

    if res == "a":
        return "brewed coffee"
    elif res == "b":
        return "mocha"
    elif res == "c":
        return "latte"
    else:
        print_message()
        return get_drink_type()

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 8</b></p>
# <p>Define a function called order_latte() that asks the user what kind of milk they would like for their latte using input() with the options: 'And what kind of milk for your latte? [a] 2% milk [b] Non-fat milk [c] Soy milk'. Store the user’s response in a variable called res.</p>

# %%
def order_latte():
    res = input(
        "And what kind of milk for your latte? \n"
        "[a] 2% milk \n"
        "[b] Non-fat milk \n"
        "[c] Soy milk \n"
        "> "
    )

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 9</b></p>
# <p>Add conditional statements to order_latte() such that if res is 'a', return 'latte'; if res is 'b', return 'non-fat latte'; and if res is 'c', return 'soy latte'. For any other input, call print_message() and return the value obtained from calling order_latte() again so that the user is prompted until a valid milk option is selected.</p>

# %%
def order_latte():
    res = input(
        "And what kind of milk for your latte? \n"
        "[a] 2% milk \n"
        "[b] Non-fat milk \n"
        "[c] Soy milk \n"
        "> "
    )

    if res == "a":
        return "latte"
    elif res == "b":
        return "non-fat latte"
    elif res == "c":
        return "soy latte"
    else:
        print_message()
        return order_latte()

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 10</b></p>
# <p>In get_drink_type(), change the behavior for the latte option so that instead of returning the string 'latte' when the user selects latte, the function returns the value obtained from calling order_latte(). Run the script and verify what gets printed when latte is selected as the drink.</p>

# %%
def get_drink_type():
    res = input(
        "What type of drink would you like? \n"
        "[a] Brewed Coffee \n"
        "[b] Mocha \n"
        "[c] Latte \n"
        "> "
    )

    if res == "a":
        return "brewed coffee"
    elif res == "b":
        return "mocha"
    elif res == "c":
        return order_latte()
    else:
        print_message()
        return get_drink_type()

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 11</b></p>
# <p>In coffee_bot(), remove any current print statements except for the welcome greeting. At the very end of coffee_bot(), add a print statement that outputs: 'Alright, that's a {size} {drink_type}!' using the values returned from get_size() and get_drink_type().</p>

# %%
def coffee_bot():
    print("Welcome to the cafe!")

    size = get_size()
    drink_type = get_drink_type()

    print(f"Alright, that's a {size} {drink_type}!")

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 12</b></p>
# <p>After confirming the drink in coffee_bot(), prompt the user for their name using input() with the message: 'Can I get your name please?'. Store the response in a variable called name.</p>

# %%
def coffee_bot():
    print("Welcome to the cafe!")

    size = get_size()
    drink_type = get_drink_type()

    print(f"Alright, that's a {size} {drink_type}!")
    name = input("Can I get your name please? \n> ")

# %% [markdown]
# <p style="font-size: 16px;"><b>Task 13</b></p>
# <p>Finally, in coffee_bot(), print a statement that says: 'Thanks, {name}! Your drink will be ready shortly.' using the name provided by the user to complete the order flow.</p>

# %%
def coffee_bot():
    print("Welcome to the cafe!")

    size = get_size()
    drink_type = get_drink_type()

    print(f"Alright, that's a {size} {drink_type}!")
    name = input("Can I get your name please? \n> ")
    print(f"Thanks, {name}! Your drink will be ready shortly.")

# %% [markdown]
# <p style="font-size: 16px;"><b>Final Code</b></p>
# <p>Finally, in coffee_bot(), print a statement that says: 'Thanks, {name}! Your drink will be ready shortly.' using the name provided by the user to complete the order flow.</p>

# %%
# Define your functions
def coffee_bot():
  print("Welcome to the cafe!")
  size = get_size()
  drink_type = get_drink_type()
  print(f"Alright, that's a {size} {drink_type}!")
  name = input("Can I get your name please? ")
  print(f"Thanks, {name}! Your {size} {drink_type} will be ready shortly.")

def get_size():
  res = input('What size drink can I get for you? \n[a] Small \n[b] Medium \n[c] Large \n> ')
  if res == "a":
    return "small"
  elif res == "b":
    return "medium"
  elif res == "c":
    return "large"
  else:
    print_message()
    return get_size()

def print_message():
  print("I'm sorry, I did not understand your selection. Please enter the corresponding letter for your response.")

def get_drink_type():
  res = input("What type of drink would you like? \n[a] Brewed Coffee \n[b] Mocha \n[c] Latte \n>")
  if res == "a":
    return "coffee"
  elif res == "b":
    return "mocha"
  elif res == "c":
    return order_latte()
  else:
    print_message()
    return get_drink_type()

def order_latte():
  res = input("And what kind of milk for your latte? \n[a] 2% milk \n[b] Non-fat milk \n[c] Soy milk \n>")
  if res == "a":
    return "latte"
  elif res == "b":
    return "non-fat latte"
  elif res == "c":
    return "soy latte"
  else:
    print_message()
    return order_latte()

# Call coffee_bot()!
coffee_bot()
# Out:
# Welcome to the cafe!
# What size drink can I get for you?
# [a] Small
# [b] Medium
# [c] Large
# > a
# What type of drink would you like?
# [a] Brewed Coffee
# [b] Mocha
# [c] Latte
# >c
# And what kind of milk for your latte?
# [a] 2% milk
# [b] Non-fat milk
# [c] Soy milk
# >c
# Alright, that's a small soy latte!
# Can I get your name please? Toni
# Thanks, Toni! Your small soy latte will be ready shortly.
